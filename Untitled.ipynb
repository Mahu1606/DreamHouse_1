# %%
import turtle 
t = turtle.Turtle()
t.speed(2)
t.pensize(2)
t.penup()
t.goto(-200,-250)
turtle.bgcolor("aqua")
t.pendown()

# Vẽ khung ngôi nhà 
t.fillcolor("blue")
t.begin_fill()
t.forward(100)
t.left(90)
t.forward(230)
t.left(90)
t.forward(200)
t.left(90)
t.forward(230)
t.left(90)
t.forward(100)
t.end_fill()
# Vẽ cửa 
t.fillcolor("lightgreen")
t.begin_fill()
t.forward(50)
t.left(90)
t.forward(115)
t.left(90)
t.forward(100)
t.left(90)
t.forward(115)
t.end_fill()
#Vẽ mái
t.right(90)
t.penup()
t.forward(50)
t.right(90)
t.forward(230)
t.pendown()
t.fillcolor("fuchsia")
t.begin_fill()
t.rt(45)
t.fd(141.42135623731)
t.rt(90)
t.fd(141.42135623731)
t.end_fill()
# Vẽ hình bình hành mái 
t.fillcolor("orange")
t.begin_fill()
t.left(80)
# t.fd(180)
t.fd(150)
t.left(100)
t.fd(141.42135623731)
t.left(80)
# t.fd(180)
t.fd(150)
t.end_fill()
# cạnh bên ngôi nhà 
t.fillcolor("yellow")
t.begin_fill()
t.left(100)
t.fd(141.42135623731)
t.left(80)
# t.fd(180)
t.fd(150)
t.right(125)
t.forward(230)
t.right(55)
# t.fd(180)
t.fd(150)
t.right(125)
t.forward(230)
t.end_fill()
# Vẽ cửa sổ
t.penup()
t.right(180)
t.fd(50)
t.left(125)
t.fd(50)
t.pendown()
t.fillcolor("brown")
t.begin_fill()
t.fd(50)
t.right(125)
t.fd(60)
t.right(55)
t.fd(50)
t.right(125)
t.fd(60)
t.end_fill()

t.penup()
t.left(90)
t.fd(50)
t.right(90)
t.fd(30)

# khung mặt trời
t.right(55)
# t.fd(180)
t.fd(150)
t.penup()
t.left(55)
t.fd(150)
t.right(90)
t.fd(50)
t.pendown()
t.fd(180)
t.back(90)
t.left(90)
t.fd(90)
t.back(180)
t.fd(90)
t.right(135)
t.fd(60)
t.back(120)
t.fd(60)
t.left(90)
t.fd(60)
t.back(120)
# Mặt trời
t.fd(60)
t.right(90)
t.fd(40)
t.left(90)
t.fillcolor("yellow")
t.begin_fill()
t.circle(40)
t.end_fill()

# tán cây 1
t.penup()
t.right(45)
t.fd(60)
t.right(90)
t.fd(120)
t.right(90)
t.fd(40)
t.fillcolor("lightgreen")
t.begin_fill()
t.pendown()
t.left(45)
t.fd(60)
t.left(135)
t.fd(84.85281374)
t.left(135)
t.fd(60)
t.end_fill()

# tán cây 2
t.penup()
t.left(135)
t.fd(42.42640687)
t.begin_fill()
t.pendown()
t.right(45)
t.fd(60)
t.left(135)
t.fd(84.85281374)
t.left(135)
t.fd(60)
t.end_fill()
t.penup()
t.left(135)
t.fd(42.42640687)
# tán 3
t.begin_fill()
t.pendown()
t.right(45)
t.fd(60)
t.left(135)
t.fd(84.85281374)
t.left(135)
t.fd(60)
t.end_fill()
t.penup()
t.left(135)
t.fd(42.42640687)
# thân cây
t.fillcolor("brown")
t.right(90)
t.begin_fill()
t.pendown()
t.fd(10)
t.left(90)
t.fd(40)
t.left(90)
t.fd(20)
t.left(90)
t.fd(40)
t.left(90)
t.fd(10)
t.end_fill()
